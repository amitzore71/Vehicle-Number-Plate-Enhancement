# %%
import sys

print(sys.executable)
print(sys.version)
# Out:
# c:\Users\BabitaPal\Downloads\Vehicle-Number-Plate-Enhancement\Vehicle-Number-Plate-Enhancement\.venv\Scripts\python.exe
# 3.12.0 (tags/v3.12.0:0fb18b0, Oct  2 2023, 13:03:39) [MSC v.1935 64 bit (AMD64)]

# %%
from pathlib import Path

DATASET_DIR = Path("../data/raw/indian-number-plates")

print("Dataset exists:", DATASET_DIR.exists())

if DATASET_DIR.exists():
    print("\nContents:")
    for item in DATASET_DIR.iterdir():
        print(item.name)
# Out:
# Dataset exists: True
#
# Contents:
# Annotations
# Indian_Number_Plates
# number_plate_annos_ocr
# number_plate_images_ocr

# %%
for folder in DATASET_DIR.iterdir():
    if folder.is_dir():
        print(f"\n📁 {folder.name}")
        
        files = list(folder.rglob("*"))
        files = [f for f in files if f.is_file()]
        
        print("Files:", len(files))
        
        for f in files[:10]:
            print("  ", f.relative_to(folder))
# Out:
# 📁 Annotations
# Files: 27
#    Annotations\Datacluster_number_plates (1).xml
#    Annotations\Datacluster_number_plates (101).xml
#    Annotations\Datacluster_number_plates (11).xml
#    Annotations\Datacluster_number_plates (16).xml
#    Annotations\Datacluster_number_plates (18).xml
#    Annotations\Datacluster_number_plates (22).xml
#    Annotations\Datacluster_number_plates (36).xml
#    Annotations\Datacluster_number_plates (38).xml
#    Annotations\Datacluster_number_plates (4).xml
#    Annotations\Datacluster_number_plates (49).xml
#
# 📁 Indian_Number_Plates
# Files: 27
#    Sample_Images\Datacluster_number_plates (1).jpg
#    Sample_Images\Datacluster_number_plates (101).jpg
#    Sample_Images\Datacluster_number_plates (11).jpg
#    Sample_Images\Datacluster_number_plates (16).jpg
#    Sample_Images\Datacluster_number_plates (18).jpg
#    Sample_Images\Datacluster_number_plates (22).jpg
#    Sample_Images\Datacluster_number_plates (36).jpg
#    Sample_Images\Datacluster_number_plates (38).jpg
#    Sample_Images\Datacluster_number_plates (4).jpg
#    Sample_Images\Datacluster_number_plates (49).jpg
#
# 📁 number_plate_annos_ocr
# Files: 20
#    number_plate_annos_ocr\dc_auto_image_000021_bMXgvtud5K.xml
#    number_plate_annos_ocr\dc_auto_image_000024_fqvRhfiO6i.xml
#    number_plate_annos_ocr\dc_bus_image_000033_XUH0eV452t.xml
#    number_plate_annos_ocr\dc_bus_image_000039_9NispLHmAo.xml
#    number_plate_annos_ocr\dc_license_plates_0RBAQHKIXQMDFYZD.xml
#    number_plate_annos_ocr\dc_license_plates_0RRPJCID3RRLSFTI.xml
#    number_plate_annos_ocr\dc_license_plates_2D9KWCA7PLD0NW31.xml
#    number_plate_annos_ocr\dc_license_plates_2DZ4YT4ZJ9XJZSO0.xml
#    number_plate_annos_ocr\dc_license_plates_3GKHBM5PWHYXHMTE.xml
#    number_plate_annos_ocr\dc_license_plates_3HE1J0YIRGRDENVO.xml
#
# 📁 number_plate_images_ocr
# Files: 21
#    number_plate_images_ocr\dc_auto_image_000021_bMXgvtud5K.jpg
#    number_plate_images_ocr\dc_auto_image_000024_fqvRhfiO6i.jpg
#    number_plate_images_ocr\dc_bus_image_000033_XUH0eV452t.jpg
#    number_plate_images_ocr\dc_bus_image_000039_9NispLHmAo.jpg
#    number_plate_images_ocr\dc_license_plates_0RBAQHKIXQMDFYZD.jpg
#    number_plate_images_ocr\dc_license_plates_0RRPJCID3RRLSFTI.jpg
#    number_plate_images_ocr\dc_license_plates_2D9KWCA7PLD0NW31.jpg
#    number_plate_images_ocr\dc_license_plates_2DZ4YT4ZJ9XJZSO0.jpg
#    number_plate_images_ocr\dc_license_plates_3GKHBM5PWHYXHMTE.jpg
#    number_plate_images_ocr\dc_license_plates_3HE1J0YIRGRDENVO.jpg
